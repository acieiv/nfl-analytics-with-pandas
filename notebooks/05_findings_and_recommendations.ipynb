# %% [markdown]
# # Findings and recommendations
#
# **Question:** What should a reader take away from this analysis?
#
# - Select the strongest supported findings.
# - Present the evidence clearly for a nontechnical reader.
# - Explain limitations and useful next questions.

# %% [markdown]
# ## Setup and inputs
#
# Add your imports, paths, and data loading below.

# %% [markdown]
# ## Analysis
#
# Add code and explanation cells as you work.

# %% [markdown]
# ## Findings and limitations
#
# Write your conclusions here after completing the analysis.
