# %% [markdown]
# # Feature Engineering with pandas\n\n**Question:** How can useful analytical variables be created efficiently from existing game and team columns?\n\n## pandas skills to practice\n- assign\n- where and mask\n- cut and qcut\n- vectorized arithmetic\n- group-derived features\n\nComplete this notebook without relying on hidden state from another notebook.

# %% [markdown]
# ## 1. Load and inspect the required data\n\nDocument the input files, row grain, important keys, and expected coverage before transforming anything.

# %% [markdown]
# ## 2. Practice the target pandas operations\n\nUse the techniques named above deliberately. Add assertions or reconciliation checks where a transformation could change row counts, keys, or meaning.

# %% [markdown]
# ## 3. Apply the operations to an NFL question\n\nChoose a focused football slice or comparison that makes the pandas operation useful rather than decorative.

# %% [markdown]
# ## 4. Validate and interpret\n\nCheck the resulting shape, keys, missing values, and important totals. Explain what the result means in plain language.

# %% [markdown]
# ## 5. Findings, limitations, and pandas recap\n\n- What did the analysis show?\n- What limitations or data-quality issues remain?\n- Which pandas techniques did this notebook demonstrate?\n- What would you change or extend next?
