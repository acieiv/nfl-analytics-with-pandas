# %% [markdown]
# # Building the analysis dataset
#
# **Question:** How can game results and team performance be combined correctly?
#
# - Define the structure of your analysis table.
# - Combine the inputs and check the result.
# - Document and save your analysis dataset.

# %% [markdown]
# ## Setup and inputs
#
# Add your imports, paths, and data loading below.

# %% [markdown]
# ## Analysis
#
# Add code and explanation cells as you work.

# %% [markdown]
# ## Findings and limitations
#
# Write your conclusions here after completing the analysis.
