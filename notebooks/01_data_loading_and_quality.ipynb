# %% [markdown]
# # Data loading and quality
#
# **Question:** What data do we have, and which records are suitable for analysis?
#
# - Identify the inputs and what one row represents.
# - Inspect data quality and season coverage.
# - Document which records you will include and why.

# %% [markdown]
# ## Setup and inputs
#
# Add your imports, paths, and data loading below.

# %% [markdown]
# ## Analysis
#
# Add code and explanation cells as you work.

# %% [markdown]
# ## Findings and limitations
#
# Write your conclusions here after completing the analysis.
