# %% [markdown]
# # What separates winning teams?
#
# **Question:** How do efficiency, turnovers, and scoring differ across outcomes?
#
# - Choose the measures and comparisons to investigate.
# - Explore patterns across teams and seasons.
# - Support your interpretation with tables or charts.

# %% [markdown]
# ## Setup and inputs
#
# Add your imports, paths, and data loading below.

# %% [markdown]
# ## Analysis
#
# Add code and explanation cells as you work.

# %% [markdown]
# ## Findings and limitations
#
# Write your conclusions here after completing the analysis.
