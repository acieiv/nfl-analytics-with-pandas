# %% [markdown]
# # Team form and consistency
#
# **Question:** Does recent team performance persist into subsequent games?
#
# - Define recent form and consistency.
# - Investigate how performance changes over time.
# - Evaluate what your results do and do not support.

# %% [markdown]
# ## Setup and inputs
#
# Add your imports, paths, and data loading below.

# %% [markdown]
# ## Analysis
#
# Add code and explanation cells as you work.

# %% [markdown]
# ## Findings and limitations
#
# Write your conclusions here after completing the analysis.
